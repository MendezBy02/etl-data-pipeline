# %% [markdown]
# Importar Librerias

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Conexion a PostgreSQL

# %%
# !pip install sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.12/dist-packages (2.0.48)
# Requirement already satisfied: psycopg2-binary in /usr/local/lib/python3.12/dist-packages (2.9.11)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy) (4.15.0)

# %%
from sqlalchemy import create_engine
database_url = "postgresql://etl_seguros_fwgm_user:FLIwCR2BnSl9vmgdqKd7GtpzOyBHRpyl@dpg-d6qu5hk50q8c73bpe0p0-a.oregon-postgres.render.com/etl_seguros_fwgm"
engine = create_engine(database_url)

# %% [markdown]
# Cargar Dataset

# %%
#En esta url va el RAW de nuestro csv subido en github
url = "https://raw.githubusercontent.com/MendezBy02/etl-data-pipeline/refs/heads/main/data/raw/corredores.csv"

corredores = pd.read_csv(url)

# %% [markdown]
# Exploración de datos

# %%
corredores.head()
# Out:
#    id_corredor               nombre         zona    nivel  anios_experiencia
# 0            1    José López Flores  Paracentral      Mid                4.0
# 1            2    José Ortiz García     Centro     Junior                0.0
# 2            3   María Ramírez Cruz       Centro  SENIOR                 6.0
# 3            4  Fernanda Rojas Cruz          NaN  SENIOR                 8.0
# 4            5      Ana Gómez Rojas          NaN   Senior                4.0

# %%
corredores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_corredor        80 non-null     int64
#  1   nombre             80 non-null     object
#  2   zona               63 non-null     object
#  3   nivel              68 non-null     object
#  4   anios_experiencia  76 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 3.3+ KB

# %%
corredores.isnull().sum()
# Out:
# id_corredor           0
# nombre                0
# zona                 17
# nivel                12
# anios_experiencia     4
# dtype: int64

# %%
corredores.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Funciones reutilizables

# %%
#Normalizar columnas

def normalizar_columnas(df):
  df.columns =(
      df.columns
      .str.strip()
      .str.lower()
      .str.replace(" ","_")
  )
  return df

# %%
#Limpiar texto

def limpiar_texto(df):

  for col in df.select_dtypes(include="object").columns:
    df[col] = df[col].astype(str).str.strip()

    df[col] = df[col].replace(
        ["nan","None","Null","null",""],
        pd.NA
        )
    return df

# %% [markdown]
# Aplicar Limpieza

# %%
corredores = normalizar_columnas(corredores)
corredores = limpiar_texto(corredores)
corredores = corredores.drop_duplicates()

# %% [markdown]
# Funciones especificas

# %%
#Normalización de nivel

map_nivel = {
    "mid": "Mid",
    "MID": "Mid",
    "SENIOR": "Senior",
    "senior": "Senior",
    "JUNIOR": "Junior",
    "junior": "Junior",
    "ELITE":"Elite" ,
    "elite" : "Elite"
}

corredores["nivel"] = (
    corredores["nivel"]
    .astype(str)
    .str.strip()
    .replace(map_nivel)
)

#Convertir a entero datos decimal
corredores["anios_experiencia"] = pd.to_numeric(
    corredores["anios_experiencia"],
    errors="coerce"
)


corredores["anios_experiencia"] = corredores["anios_experiencia"].astype("Int64")

# %%
corredores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_corredor        80 non-null     int64
#  1   nombre             80 non-null     object
#  2   zona               63 non-null     object
#  3   nivel              80 non-null     object
#  4   anios_experiencia  76 non-null     Int64
# dtypes: Int64(1), int64(1), object(3)
# memory usage: 3.3+ KB

# %%
corredores.head()
# Out:
#    id_corredor               nombre         zona   nivel  anios_experiencia
# 0            1    José López Flores  Paracentral     Mid                  4
# 1            2    José Ortiz García     Centro    Junior                  0
# 2            3   María Ramírez Cruz       Centro  Senior                  6
# 3            4  Fernanda Rojas Cruz          NaN  Senior                  8
# 4            5      Ana Gómez Rojas          NaN  Senior                  4

# %% [markdown]
# Separar validos y rechazados

# %%
#Primero debemos colocar que reglas queremos tener para poder separarlos entra validos y rechazados
#Reglas
#1. Los tipo ID's deben ser not null
#2. No debe haber datos vacios

columnas_obligatorias = [
   "id_corredor",
   "nombre",
   "zona",
   "anios_experiencia"
]

condicion_nulos = corredores[columnas_obligatorias].isna().any(axis=1)

condicion_exp_invalida = (
     (corredores["anios_experiencia"] < 0) |
    (corredores["anios_experiencia"] > 50)
)

condicion_rechazo = condicion_nulos | condicion_exp_invalida

rechazados = corredores.loc[condicion_rechazo].copy()
validos = corredores.loc[~condicion_rechazo].copy()

# %% [markdown]
# Motivo del rechazo

# %%
from pandas.core.dtypes.missing import isna
def motivo(row):

  motivos = []

  if pd.isna(row["id_corredor"]):
    motivos.append("ID_no_valido")

  if pd.isna(row["nombre"]):
    motivos.append("Nombre_nulo")

  if pd.isna(row["zona"]):
    motivos.append("Zona_nula")

  if pd.isna(row["anios_experiencia"]):
    motivos.append("anios_experiencia_nulo")

  elif row["anios_experiencia"] > 50:
      motivos.append("Experiencia_fuera_de_rango")

  return ",".join(motivos)

# %% [markdown]
# Agregar motivo de rechazo

# %%
rechazados["motivo_rechazo"] = rechazados.apply(motivo, axis=1)

# %% [markdown]
# Exportar Archivos

# %%
validos.to_csv("corredores_curated.csv", index=False)
rechazados.to_csv("corredores_rejects.csv", index=False)

# %% [markdown]
# Cargar datos en PostgreSQL

# %% [markdown]
# Para evitar errores de carga y mostrar los detalles

# %%
corredores.head()
# Out:
#    id_corredor               nombre         zona   nivel  anios_experiencia
# 0            1    José López Flores  Paracentral     Mid                  4
# 1            2    José Ortiz García     Centro    Junior                  0
# 2            3   María Ramírez Cruz       Centro  Senior                  6
# 3            4  Fernanda Rojas Cruz          NaN  Senior                  8
# 4            5      Ana Gómez Rojas          NaN  Senior                  4

# %%
corredores.dtypes
# Out:
# id_corredor           int64
# nombre               object
# zona                 object
# nivel                object
# anios_experiencia     Int64
# dtype: object

# %%
corredores.isnull().sum()
# Out:
# id_corredor           0
# nombre                0
# zona                 17
# nivel                 0
# anios_experiencia     4
# dtype: int64

# %%
corredores.value_counts()
# Out:
# id_corredor  nombre                       zona         nivel   anios_experiencia
# 1            José López Flores            Paracentral  Mid     4                    1
# 2            José Ortiz García              Centro     Junior  0                    1
# 3            María Ramírez Cruz           Centro       Senior  6                    1
# 6            Sofía Reyes Hernández        Occidente    Elite   3                    1
# 7            Pedro Vásquez Torres         Costa        nan     1                    1
# 8            Paula Ortiz Hernández          Centro     Junior  17                   1
# 9            Carlos Torres Vásquez        Paracentral  Junior  2                    1
# 10           Juan Cruz Castillo           Occidente    nan     7                    1
# 13           Valeria García Torres        Oriente      Senior  23                   1
# 14           Diego Gómez Chávez             Centro     Senior  20                   1
# 16           Juan Reyes Morales           Costa        Junior  6                    1
# 18           Paula Pérez Flores           Oriente      Mid     23                   1
# 19           Fernanda Ortiz Flores          Centro     Senior  12                   1
# 21           Juan Hernández Pérez         Oriente      nan     21                   1
# 22           Andrés Torres García           Centro     Elite   19                   1
# 23           Paula Mendoza Flores         Centro       Junior  23                   1
# 25           Andrés Gómez Chávez          Centro       Junior  23                   1
# 26           Valeria Mendoza Gómez        Occidente    nan     20                   1
# 27           Carlos Mendoza Torres        Paracentral  Mid     11                   1
# 28           Carmen Ortiz Mendoza         Centro       Senior  10                   1
# 30           Carlos Cruz Martínez         Paracentral  Senior  2                    1
# 31           María Aguilar García         Oriente      Mid     21                   1
# 32           Ricardo Ortiz Gómez          Costa        Senior  99                   1
# 33           Karla Rojas Ramírez          Paracentral  Junior  9                    1
# 35           Diego García Reyes           Centro       Senior  17                   1
# 36           Diego Santos Cruz            Centro       Junior  22                   1
# 37           Juan Cruz García             Centro       nan     10                   1
# 38           María Mendoza Cruz           Costa        Junior  15                   1
# 40           Ricardo Rojas Ramírez        Occidente    Junior  21                   1
# 41           Andrés Vásquez Rojas           Centro     Elite   99                   1
# 42           Juan Hernández Martínez        Centro     Junior  10                   1
# 43           José Cruz Ramírez            Paracentral  Senior  14                   1
# 44           Luis Rojas Gómez             Costa        Elite   7                    1
# 45           María Chávez Ortiz           Occidente    Junior  20                   1
# 46           Fernanda López García        Paracentral  Mid     13                   1
# 47           Ricardo Aguilar Ramírez        Centro     Junior  5                    1
# 48           Lucía López Morales          Costa        nan     25                   1
# 50           Carlos Ramírez Martínez      Centro       Junior  10                   1
# 52           Daniela Gómez Martínez       Occidente    nan     5                    1
# 53           María Torres García          Paracentral  Elite   3                    1
# 54           Jorge Cruz Santos            Centro       Senior  2                    1
# 56           Marta Cruz Flores              Centro     Mid     21                   1
# 57           Carlos Chávez Reyes          Occidente    Junior  14                   1
# 58           Karla Santos Hernández       Occidente    Senior  6                    1
# 62           Fernanda Castillo Hernández  Oriente      Senior  3                    1
# 63           José Ortiz Pérez             Costa        Senior  19                   1
# 64           Sofía Reyes Ramírez          Costa        Senior  15                   1
# 65           Valeria Martínez García        Centro     nan     8                    1
# 66           Juan López Reyes             Oriente      Junior  8                    1
# 67           Carmen Chávez Ortiz            Centro     Senior  0                    1
# 68           José García Pérez            Centro       nan     11                   1
# 69           Jorge Ortiz Pérez              Centro     Mid     1                    1
# 71           Diego Hernández Vásquez        Centro     Senior  23                   1
# 72           Luis Cruz Gómez              Oriente      Elite   0                    1
# 73           Carmen Reyes Rojas           Paracentral  Senior  5                    1
# 75           Paula Vásquez Castillo       Paracentral  Mid     0                    1
# 76           Sofía Morales Reyes          Costa        nan     2                    1
# 78           Fernanda Reyes López         Occidente    Senior  5                    1
# 79           Jorge Flores Martínez        Occidente    Senior  13                   1
# 80           Pedro Reyes Rojas            Occidente    Elite   18                   1
# Name: count, dtype: int64

# %%
validos.to_sql(
    "corredores",
    engine,
    if_exists="append",
    index=False
  )
# Out:
# 58

# %% [markdown]
# Validar Carga

# %%
pd.read_sql(
    "Select * From corredores Limit 100",
    engine
)
# Out:
#     id_corredor                  nombre         zona   nivel  \
# 0             1       José López Flores  Paracentral     Mid
# 1             2       José Ortiz García     Centro    Junior
# 2             3      María Ramírez Cruz       Centro  Senior
# 3             6   Sofía Reyes Hernández    Occidente   Elite
# 4             7    Pedro Vásquez Torres        Costa     nan
# ..          ...                     ...          ...     ...
# 95           53     María Torres García  Paracentral   Elite
# 96           54       Jorge Cruz Santos       Centro  Senior
# 97           56       Marta Cruz Flores     Centro       Mid
# 98           57     Carlos Chávez Reyes    Occidente  Junior
# 99           58  Karla Santos Hernández    Occidente  Senior
#
#     anios_experiencia
# 0                   4
# 1                   0
# 2                   6
# 3                   3
# 4                   1
# ..                ...
# 95                  3
# 96                  2
# 97                 21
# 98                 14
# 99                  6
#
# [100 rows x 5 columns]
